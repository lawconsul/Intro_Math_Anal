# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 30)
#pd.set_option('display.width', 800)

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from pylab import rcParams
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %%
def f(x):
    return x**3 - x**2

# %%
x_arr = np.arange(-0.25, 1.05, 0.01)
y_arr = f(x_arr)

# %%
x_null = np.array([0,1])
y_null = f(x_null)

# %%
plt.scatter(x_null, y_null)
plt.plot(x_arr, y_arr)
plt.xlabel('Y')
plt.ylabel('X')
plt.show()

# %%
x_arr = np.arange(-0.25, 1.05, 0.01)
y_arr = f(x_arr)

# %%
x_null = np.array([1/3])
y_null = f(x_null)

# %%
plt.scatter(x_null, y_null)
plt.plot(x_arr, y_arr)
plt.xlabel('Y')
plt.ylabel('X')
plt.show()
